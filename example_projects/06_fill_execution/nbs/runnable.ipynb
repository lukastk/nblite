# %% [markdown]
# # Runnable Notebook
#
# This notebook can be executed with `nbl fill`.

# %%
import time
print("Starting execution...")
# Out:
# Starting execution...

# %%
# Some computation
result = sum(range(100))
print(f"Sum of 0-99: {result}")
# Out:
# Sum of 0-99: 4950

# %%
# Final output
print("Execution complete!")
result
# Out:
# Execution complete!
# 4950
