# %% [markdown]
# # Versioned
#
# Author: Jane Doe
# Version: 1.2.3
# Description: A versioned module

# %%
# |default_exp versioned

# %%
# |export

__author__ = "Jane Doe"
__version__ = "1.2.3"

# %%
# |export


def hello():
    """Say hello."""
    return f"Hello from versioned v{__version__}!"
