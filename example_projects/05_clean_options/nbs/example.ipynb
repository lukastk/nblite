# %% [markdown]
# # Clean Options Demo
#
# This notebook demonstrates cleaning options.

# %%
# This cell has an execution count and metadata
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Cell with output
2 + 2
# Out:
# 4

# %%
# Another cell
for i in range(3):
    print(f"Item {i}")
# Out:
# Item 0
# Item 1
# Item 2
