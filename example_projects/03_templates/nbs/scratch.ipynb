# %% [markdown]
# # Scratch Pad
#
# Data analysis notebook.

# %% [markdown]
# ## Setup

# %%
#|eval: false

# %% [markdown]
# ## Load Data

# %%
#|eval: false

# Load your data here
# df = pd.read_csv("data.csv")

# %% [markdown]
# ## Analysis

# %%
# Your analysis code here
