# %% [markdown]
# # My script
#
# A simple script notebook.

# %%
#|default_exp my_script

# %%
#|export

def main():
    """Main entry point."""
    print("Hello from my_script!")
    return 0

# %%
if __name__ == "__main__":
    main()
