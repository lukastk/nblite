# %% [markdown]
# # My Analysis
#
# Data analysis notebook.

# %%
#|default_exp my_analysis

# %% [markdown]
# ## Setup

# %%
#|export
#|eval: false

# %% [markdown]
# ## Load Data

# %%
#|eval: false

# Load your data here
# df = pd.read_csv("data.csv")

# %% [markdown]
# ## Analysis

# %%
# Your analysis code here
