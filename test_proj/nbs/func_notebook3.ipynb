# %% [markdown]
# # func_notebook 3
#
# Notebook function that uses the `#|return_line` directive

# %%
#|default_exp test_func_nb3
#|export_as_func true

# %%
#|hide
import nblite; from nblite import show_doc; nblite.nbl_export()
# Out:
# Environment variable DISABLE_NBLITE_EXPORT is set to True, skipping export.

# %%
#|export
print("This will be in the body of the function.")
my_val = "Hello, world!"

my_val #|return_line
# Out:
# This will be in the body of the function.
# 'Hello, world!'
